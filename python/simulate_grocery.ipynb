# %%
import pandas as pd
import numpy as np

orig_data = pd.read_csv('data/food-footprints.csv')
orig_data
# Out:
#                Entity  Code  Year  \
# 0              Apples   NaN  2010
# 1             Bananas   NaN  2010
# 2              Barley   NaN  2010
# 3    Beef (beef herd)   NaN  2010
# 4   Beef (dairy herd)   NaN  2010
# 5          Beet Sugar   NaN  2010
# 6    Berries & Grapes   NaN  2010
# 7           Brassicas   NaN  2010
# 8          Cane Sugar   NaN  2010
# 9             Cassava   NaN  2010
# 10             Cheese   NaN  2010
# 11       Citrus Fruit   NaN  2010
# 12             Coffee   NaN  2010
# 13     Dark Chocolate   NaN  2010
# 14               Eggs   NaN  2010
# 15      Fish (farmed)   NaN  2010
# 16         Groundnuts   NaN  2010
# 17      Lamb & Mutton   NaN  2010
# 18              Maize   NaN  2010
# 19               Milk   NaN  2010
# 20               Nuts   NaN  2010
# 21            Oatmeal   NaN  2010
# 22     Onions & Leeks   NaN  2010
# 23        Other Fruit   NaN  2010
# 24       Other Pulses   NaN  2010
# 25   Other Vegetables   NaN  2010
# 26               Peas   NaN  2010
# 27           Pig Meat   NaN  2010
# 28           Potatoes   NaN  2010
# 29       Poultry Meat   NaN  2010
# 30    Prawns (farmed)   NaN  2010
# 31               Rice   NaN  2010
# 32    Root Vegetables   NaN  2010
# 33            Soymilk   NaN  2010
# 34    Tofu (soybeans)   NaN  2010
# 35           Tomatoes   NaN  2010
# 36        Wheat & Rye   NaN  2010
# 37               Wine   NaN  2010
#
#     GHG emissions per kilogram (Poore & Nemecek, 2018)
# 0                                                0.43
# 1                                                0.86
# 2                                                1.18
# 3                                               99.48
# 4                                               33.30
# 5                                                1.81
# 6                                                1.53
# 7                                                0.51
# 8                                                3.20
# 9                                                1.32
# 10                                              23.88
# 11                                               0.39
# 12                                              28.53
# 13                                              46.65
# 14                                               4.67
# 15                                              13.63
# 16                                               3.23
# 17                                              39.72
# 18                                               1.70
# 19                                               3.15
# 20                                               0.43
# 21                                               2.48
# 22                                               0.50
# 23                                               1.05
# 24                                               1.79
# 25                                               0.53
# 26                                               0.98
# 27                                              12.31
# 28                                               0.46
# 29                                               9.87
# 30                                              26.87
# 31                                               4.45
# 32                                               0.43
# 33                                               0.98
# 34                                               3.16
# 35                                               2.09
# 36                                               1.57
# 37                                               1.79

# %%
orig_dict = orig_data[["Entity", "GHG emissions per kilogram (Poore & Nemecek, 2018)"]].to_dict()

# %%
item_pairs = list(zip(orig_dict["Entity"].values(), orig_dict["GHG emissions per kilogram (Poore & Nemecek, 2018)"].values()))

# %%
sim_list = []

for i in range(len(item_pairs)):
    k = np.random.randint(3, 10)
    for v in range(k):
        co2_mean = item_pairs[i][1]
        co2 = np.random.normal(co2_mean, co2_mean/5, 1)[0]
        
        if co2 <= 0:
            co2 = co2_mean
        
        weight = np.random.normal(co2_mean * 30, co2_mean * 30/5, 1)[0]
        price = np.random.normal(weight * 5, weight/2, 1)[0]
        calories = np.random.normal(weight * 6, weight/3, 1)[0]
        health_score = np.random.normal(price * 4, weight/3, 1)[0]

        sim_list.append([item_pairs[i][0], str(item_pairs[i][0]) + "-" + str(v), round(weight, 2) , round(price, 2), round(calories, 2), round(health_score, 2), round(co2, 2) ])

# %%
sim_list
# Out:
# [['Apples', 'Apples-0', 14.78, 66.97, 77.68, 267.47, 0.43],
#  ['Apples', 'Apples-1', 10.72, 56.73, 59.31, 225.46, 0.5],
#  ['Apples', 'Apples-2', 15.47, 79.07, 100.04, 312.04, 0.24],
#  ['Bananas', 'Bananas-0', 22.47, 101.36, 146.21, 400.53, 0.95],
#  ['Bananas', 'Bananas-1', 26.25, 134.98, 152.01, 536.4, 0.7],
#  ['Bananas', 'Bananas-2', 22.45, 111.37, 130.63, 442.87, 0.6],
#  ['Bananas', 'Bananas-3', 25.14, 137.4, 150.09, 549.7, 0.61],
#  ['Bananas', 'Bananas-4', 35.75, 213.96, 206.89, 859.86, 0.85],
#  ['Bananas', 'Bananas-5', 31.73, 157.83, 207.96, 637.42, 0.61],
#  ['Bananas', 'Bananas-6', 25.2, 120.95, 149.69, 496.81, 0.9],
#  ['Bananas', 'Bananas-7', 27.97, 146.9, 167.28, 574.61, 1.0],
#  ['Bananas', 'Bananas-8', 20.15, 99.74, 133.67, 410.24, 0.61],
#  ['Barley', 'Barley-0', 34.25, 186.43, 190.79, 733.19, 1.58],
#  ['Barley', 'Barley-1', 31.01, 177.55, 193.25, 699.8, 1.23],
#  ['Barley', 'Barley-2', 34.07, 177.73, 210.72, 712.24, 1.36],
#  ['Barley', 'Barley-3', 42.72, 225.52, 258.44, 893.39, 1.48],
#  ['Barley', 'Barley-4', 32.63, 180.88, 191.38, 710.31, 1.0],
#  ['Barley', 'Barley-5', 26.32, 116.27, 167.13, 479.31, 1.55],
#  ['Beef (beef herd)',
#   'Beef (beef herd)-0',
#   3889.11,
#   18968.57,
#   23904.56,
#   75512.46,
#   109.96],
#  ['Beef (beef herd)',
#   'Beef (beef herd)-1',
#   2638.15,
#   15119.39,
#   16504.21,
#   62242.15,
#   118.27],
#  ['Beef (beef herd)',
#   'Beef (beef herd)-2',
#   2941.05,
#   16274.22,
#   16634.65,
#   65083.15,
#   103.78],
#  ['Beef (beef herd)',
#   'Beef (beef herd)-3',
#   2769.47,
#   14402.53,
#   16702.91,
#   56773.56,
#   100.36],
#  ['Beef (beef herd)',
#   'Beef (beef herd)-4',
#   3533.44,
#   18852.11,
#   20088.74,
#   74778.52,
#   139.36],
#  ['Beef (dairy herd)',
#   'Beef (dairy herd)-0',
#   1180.94,
#   5068.67,
#   7608.85,
#   20272.53,
#   27.95],
#  ['Beef (dairy herd)',
#   'Beef (dairy herd)-1',
#   731.29,
#   4108.64,
#   4634.81,
#   16440.9,
#   30.06],
#  ['Beef (dairy herd)',
#   'Beef (dairy herd)-2',
#   861.05,
#   5169.54,
#   4841.84,
#   20433.29,
#   39.97],
#  ['Beet Sugar', 'Beet Sugar-0', 69.53, 299.78, 400.83, 1224.91, 2.5],
#  ['Beet Sugar', 'Beet Sugar-1', 52.67, 241.39, 295.87, 940.84, 1.47],
#  ['Beet Sugar', 'Beet Sugar-2', 38.88, 237.87, 222.89, 959.02, 2.1],
#  ['Beet Sugar', 'Beet Sugar-3', 44.79, 219.78, 250.0, 913.68, 2.63],
#  ['Beet Sugar', 'Beet Sugar-4', 59.79, 275.34, 371.39, 1074.58, 1.79],
#  ['Beet Sugar', 'Beet Sugar-5', 45.28, 239.28, 287.24, 933.52, 1.78],
#  ['Beet Sugar', 'Beet Sugar-6', 82.28, 416.67, 489.22, 1664.19, 1.7],
#  ['Beet Sugar', 'Beet Sugar-7', 49.51, 256.75, 302.32, 1041.69, 2.26],
#  ['Beet Sugar', 'Beet Sugar-8', 62.59, 344.64, 383.24, 1391.14, 0.95],
#  ['Berries & Grapes', 'Berries & Grapes-0', 45.6, 200.71, 288.0, 785.13, 1.3],
#  ['Berries & Grapes',
#   'Berries & Grapes-1',
#   29.61,
#   164.77,
#   184.79,
#   653.92,
#   1.07],
#  ['Berries & Grapes',
#   'Berries & Grapes-2',
#   41.99,
#   234.26,
#   234.46,
#   937.51,
#   1.4],
#  ['Berries & Grapes',
#   'Berries & Grapes-3',
#   49.0,
#   231.13,
#   262.15,
#   895.94,
#   1.89],
#  ['Berries & Grapes',
#   'Berries & Grapes-4',
#   43.87,
#   234.59,
#   264.0,
#   918.36,
#   1.53],
#  ['Brassicas', 'Brassicas-0', 12.1, 54.85, 65.26, 225.02, 0.28],
#  ['Brassicas', 'Brassicas-1', 13.6, 68.13, 76.04, 278.82, 0.49],
#  ['Brassicas', 'Brassicas-2', 12.75, 58.55, 73.23, 229.58, 0.57],
#  ['Brassicas', 'Brassicas-3', 17.25, 75.37, 110.37, 298.76, 0.61],
#  ['Brassicas', 'Brassicas-4', 15.43, 76.9, 91.45, 306.2, 0.46],
#  ['Brassicas', 'Brassicas-5', 20.51, 91.1, 118.09, 352.38, 0.43],
#  ['Brassicas', 'Brassicas-6', 16.87, 74.88, 103.06, 300.12, 0.28],
#  ['Brassicas', 'Brassicas-7', 14.78, 77.53, 86.65, 318.77, 0.52],
#  ['Brassicas', 'Brassicas-8', 14.99, 69.2, 89.98, 271.55, 0.6],
#  ['Cane Sugar', 'Cane Sugar-0', 78.12, 349.65, 436.04, 1402.89, 3.42],
#  ['Cane Sugar', 'Cane Sugar-1', 117.1, 591.5, 688.89, 2414.13, 3.71],
#  ['Cane Sugar', 'Cane Sugar-2', 91.79, 402.49, 558.29, 1642.62, 2.15],
#  ['Cane Sugar', 'Cane Sugar-3', 96.56, 571.23, 550.07, 2280.96, 3.65],
#  ['Cane Sugar', 'Cane Sugar-4', 107.57, 568.39, 672.37, 2235.68, 2.7],
#  ['Cassava', 'Cassava-0', 42.48, 190.54, 265.52, 759.95, 1.25],
#  ['Cassava', 'Cassava-1', 45.77, 254.56, 261.4, 1012.52, 1.42],
#  ['Cassava', 'Cassava-2', 20.45, 99.62, 117.48, 403.59, 1.91],
#  ['Cassava', 'Cassava-3', 36.73, 223.23, 211.53, 898.57, 1.65],
#  ['Cheese', 'Cheese-0', 733.72, 3844.3, 4215.43, 15258.53, 21.26],
#  ['Cheese', 'Cheese-1', 791.23, 3823.47, 4992.06, 15536.83, 32.79],
#  ['Cheese', 'Cheese-2', 1090.53, 5058.43, 6064.98, 20305.17, 25.95],
#  ['Cheese', 'Cheese-3', 634.79, 3041.57, 3837.52, 12259.67, 20.0],
#  ['Cheese', 'Cheese-4', 624.24, 3286.33, 4026.81, 12906.56, 23.85],
#  ['Citrus Fruit', 'Citrus Fruit-0', 13.83, 73.45, 85.04, 284.37, 0.36],
#  ['Citrus Fruit', 'Citrus Fruit-1', 11.8, 48.44, 76.1, 194.42, 0.37],
#  ['Citrus Fruit', 'Citrus Fruit-2', 9.9, 59.18, 56.48, 234.4, 0.4],
#  ['Citrus Fruit', 'Citrus Fruit-3', 8.7, 39.75, 52.64, 162.68, 0.35],
#  ['Coffee', 'Coffee-0', 1056.41, 5566.98, 6210.99, 22241.41, 29.94],
#  ['Coffee', 'Coffee-1', 1164.29, 5204.52, 7048.86, 21089.23, 27.67],
#  ['Coffee', 'Coffee-2', 893.02, 4588.39, 5571.73, 18237.67, 25.27],
#  ['Dark Chocolate',
#   'Dark Chocolate-0',
#   1672.07,
#   7925.8,
#   9705.56,
#   32505.23,
#   46.51],
#  ['Dark Chocolate',
#   'Dark Chocolate-1',
#   1628.18,
#   8686.93,
#   9914.87,
#   34025.14,
#   48.18],
#  ['Dark Chocolate',
#   'Dark Chocolate-2',
#   1737.86,
#   10317.3,
#   11119.36,
#   41492.03,
#   40.98],
#  ['Dark Chocolate',
#   'Dark Chocolate-3',
#   1199.36,
#   5886.86,
#   7114.11,
#   24439.75,
#   39.85],
#  ['Eggs', 'Eggs-0', 132.26, 687.8, 762.72, 2769.73, 2.13],
#  ['Eggs', 'Eggs-1', 153.71, 790.92, 919.29, 3074.28, 4.21],
#  ['Eggs', 'Eggs-2', 147.87, 648.79, 831.21, 2551.62, 5.89],
#  ['Eggs', 'Eggs-3', 132.3, 644.21, 816.67, 2552.15, 3.99],
#  ['Eggs', 'Eggs-4', 89.25, 455.45, 537.18, 1773.58, 2.89],
#  ['Eggs', 'Eggs-5', 120.45, 638.48, 635.44, 2496.74, 5.11],
#  ['Eggs', 'Eggs-6', 101.96, 532.01, 607.36, 2147.03, 5.89],
#  ['Fish (farmed)', 'Fish (farmed)-0', 445.11, 2040.21, 2974.2, 8407.71, 12.23],
#  ['Fish (farmed)',
#   'Fish (farmed)-1',
#   336.16,
#   1665.75,
#   2074.21,
#   6819.32,
#   15.53],
#  ['Fish (farmed)', 'Fish (farmed)-2', 298.76, 1355.25, 1730.55, 5465.2, 10.86],
#  ['Fish (farmed)', 'Fish (farmed)-3', 409.91, 1922.6, 2776.74, 7708.69, 16.58],
#  ['Fish (farmed)',
#   'Fish (farmed)-4',
#   478.54,
#   2623.54,
#   2666.04,
#   10638.95,
#   17.18],
#  ['Groundnuts', 'Groundnuts-0', 74.43, 390.31, 452.75, 1601.93, 4.54],
#  ['Groundnuts', 'Groundnuts-1', 102.38, 566.77, 631.8, 2232.79, 3.63],
#  ['Groundnuts', 'Groundnuts-2', 112.13, 539.67, 677.42, 2176.49, 2.93],
#  ['Lamb & Mutton',
#   'Lamb & Mutton-0',
#   1173.78,
#   6828.29,
#   6553.0,
#   27712.44,
#   62.4],
#  ['Lamb & Mutton',
#   'Lamb & Mutton-1',
#   899.26,
#   4572.51,
#   5051.43,
#   17947.75,
#   23.68],
#  ['Lamb & Mutton',
#   'Lamb & Mutton-2',
#   1385.8,
#   7196.49,
#   8443.97,
#   28825.91,
#   45.55],
#  ['Lamb & Mutton',
#   'Lamb & Mutton-3',
#   1149.01,
#   5488.96,
#   6538.32,
#   22638.32,
#   40.43],
#  ['Lamb & Mutton',
#   'Lamb & Mutton-4',
#   762.44,
#   4292.88,
#   4531.69,
#   17353.65,
#   34.61],
#  ['Lamb & Mutton',
#   'Lamb & Mutton-5',
#   835.89,
#   3852.59,
#   5132.19,
#   15518.83,
#   46.85],
#  ['Maize', 'Maize-0', 66.41, 348.95, 427.31, 1387.71, 1.67],
#  ['Maize', 'Maize-1', 47.72, 267.3, 272.27, 1036.72, 1.74],
#  ['Maize', 'Maize-2', 62.69, 343.64, 355.19, 1407.23, 1.75],
#  ['Milk', 'Milk-0', 75.45, 360.85, 480.04, 1471.36, 3.46],
#  ['Milk', 'Milk-1', 63.57, 309.36, 361.06, 1243.78, 2.63],
#  ['Milk', 'Milk-2', 108.98, 530.47, 620.41, 2115.29, 3.01],
#  ['Milk', 'Milk-3', 111.07, 484.09, 628.84, 1943.11, 2.72],
#  ['Milk', 'Milk-4', 122.87, 595.16, 679.67, 2354.43, 3.7],
#  ['Milk', 'Milk-5', 110.8, 615.75, 630.51, 2423.93, 3.45],
#  ['Milk', 'Milk-6', 138.33, 675.84, 854.7, 2737.25, 4.13],
#  ['Milk', 'Milk-7', 72.88, 448.21, 415.16, 1821.2, 3.33],
#  ['Nuts', 'Nuts-0', 9.01, 44.18, 51.54, 175.28, 0.42],
#  ['Nuts', 'Nuts-1', 13.9, 64.81, 85.65, 268.24, 0.2],
#  ['Nuts', 'Nuts-2', 15.17, 70.96, 89.36, 283.79, 0.34],
#  ['Nuts', 'Nuts-3', 11.83, 51.32, 71.39, 204.94, 0.55],
#  ['Nuts', 'Nuts-4', 13.15, 68.15, 81.15, 276.21, 0.51],
#  ['Nuts', 'Nuts-5', 9.54, 46.5, 51.31, 187.54, 0.35],
#  ['Nuts', 'Nuts-6', 15.46, 70.11, 87.26, 278.41, 0.54],
#  ['Nuts', 'Nuts-7', 13.6, 62.49, 80.18, 257.42, 0.38],
#  ['Nuts', 'Nuts-8', 16.21, 75.44, 83.41, 299.8, 0.38],
#  ['Oatmeal', 'Oatmeal-0', 57.59, 312.85, 359.17, 1251.05, 2.2],
#  ['Oatmeal', 'Oatmeal-1', 78.16, 352.11, 446.94, 1418.84, 2.72],
#  ['Oatmeal', 'Oatmeal-2', 38.22, 185.98, 222.39, 757.28, 3.15],
#  ['Oatmeal', 'Oatmeal-3', 61.5, 313.25, 354.92, 1250.91, 3.6],
#  ['Oatmeal', 'Oatmeal-4', 61.32, 348.19, 393.26, 1386.09, 2.61],
#  ['Oatmeal', 'Oatmeal-5', 64.7, 339.08, 404.53, 1337.53, 2.62],
#  ['Oatmeal', 'Oatmeal-6', 79.79, 374.71, 457.04, 1539.8, 2.93],
#  ['Oatmeal', 'Oatmeal-7', 83.36, 392.58, 471.44, 1508.78, 2.2],
#  ['Oatmeal', 'Oatmeal-8', 66.19, 372.39, 403.12, 1526.33, 1.9],
#  ['Onions & Leeks', 'Onions & Leeks-0', 11.19, 52.55, 66.93, 213.43, 0.34],
#  ['Onions & Leeks', 'Onions & Leeks-1', 19.16, 102.73, 119.7, 414.84, 0.45],
#  ['Onions & Leeks', 'Onions & Leeks-2', 15.84, 80.07, 103.77, 328.32, 0.48],
#  ['Onions & Leeks', 'Onions & Leeks-3', 11.92, 60.06, 70.83, 243.26, 0.41],
#  ['Onions & Leeks', 'Onions & Leeks-4', 12.5, 63.37, 75.49, 256.39, 0.63],
#  ['Onions & Leeks', 'Onions & Leeks-5', 20.62, 102.99, 119.78, 421.08, 0.51],
#  ['Onions & Leeks', 'Onions & Leeks-6', 14.76, 91.0, 90.23, 358.52, 0.59],
#  ['Onions & Leeks', 'Onions & Leeks-7', 17.63, 79.15, 101.5, 308.66, 0.61],
#  ['Onions & Leeks', 'Onions & Leeks-8', 15.37, 75.33, 89.35, 300.36, 0.48],
#  ['Other Fruit', 'Other Fruit-0', 24.01, 112.63, 145.32, 437.38, 1.19],
#  ['Other Fruit', 'Other Fruit-1', 46.27, 248.43, 277.62, 1014.7, 1.04],
#  ['Other Fruit', 'Other Fruit-2', 28.84, 126.78, 182.9, 499.07, 1.27],
#  ['Other Fruit', 'Other Fruit-3', 37.33, 210.35, 219.97, 851.42, 0.69],
#  ['Other Fruit', 'Other Fruit-4', 30.36, 140.85, 174.54, 583.69, 1.12],
#  ['Other Fruit', 'Other Fruit-5', 24.26, 123.41, 144.35, 491.05, 0.97],
#  ['Other Fruit', 'Other Fruit-6', 33.79, 172.97, 192.48, 690.94, 1.18],
#  ['Other Fruit', 'Other Fruit-7', 22.97, 116.5, 139.07, 468.48, 0.99],
#  ['Other Fruit', 'Other Fruit-8', 41.31, 180.24, 265.16, 723.15, 0.9],
#  ['Other Pulses', 'Other Pulses-0', 68.84, 332.82, 402.25, 1305.54, 1.89],
#  ['Other Pulses', 'Other Pulses-1', 59.74, 282.92, 362.82, 1118.57, 1.97],
#  ['Other Pulses', 'Other Pulses-2', 75.87, 344.35, 428.22, 1359.51, 1.21],
#  ['Other Pulses', 'Other Pulses-3', 48.94, 215.97, 302.6, 851.54, 1.45],
#  ['Other Pulses', 'Other Pulses-4', 70.56, 372.43, 414.79, 1541.13, 1.86],
#  ['Other Vegetables',
#   'Other Vegetables-0',
#   18.18,
#   84.36,
#   112.29,
#   339.43,
#   0.74],
#  ['Other Vegetables', 'Other Vegetables-1', 19.6, 97.31, 116.52, 390.16, 0.62],
#  ['Other Vegetables', 'Other Vegetables-2', 16.62, 71.88, 98.29, 282.47, 0.68],
#  ['Other Vegetables',
#   'Other Vegetables-3',
#   18.04,
#   95.71,
#   105.77,
#   379.18,
#   0.81],
#  ['Peas', 'Peas-0', 17.27, 86.9, 109.21, 352.28, 0.77],
#  ['Peas', 'Peas-1', 32.43, 167.08, 182.47, 667.06, 0.93],
#  ['Peas', 'Peas-2', 35.7, 175.93, 215.69, 691.74, 0.99],
#  ['Peas', 'Peas-3', 31.98, 153.02, 186.99, 612.56, 0.99],
#  ['Pig Meat', 'Pig Meat-0', 381.43, 1617.22, 2205.26, 6532.39, 12.58],
#  ['Pig Meat', 'Pig Meat-1', 368.97, 2007.01, 2364.0, 8227.18, 12.76],
#  ['Pig Meat', 'Pig Meat-2', 405.94, 2186.22, 2547.67, 8820.65, 12.61],
#  ['Pig Meat', 'Pig Meat-3', 393.1, 1844.81, 2392.37, 7471.62, 11.63],
#  ['Pig Meat', 'Pig Meat-4', 404.72, 2197.82, 2405.32, 8942.1, 13.5],
#  ['Pig Meat', 'Pig Meat-5', 277.94, 1662.37, 1638.17, 6548.58, 12.12],
#  ['Pig Meat', 'Pig Meat-6', 406.29, 1705.37, 2597.73, 6810.54, 16.23],
#  ['Potatoes', 'Potatoes-0', 13.41, 76.91, 72.31, 303.87, 0.44],
#  ['Potatoes', 'Potatoes-1', 16.8, 78.06, 102.95, 304.15, 0.47],
#  ['Potatoes', 'Potatoes-2', 10.13, 38.66, 65.05, 159.39, 0.52],
#  ['Potatoes', 'Potatoes-3', 14.27, 64.97, 79.21, 257.97, 0.36],
#  ['Potatoes', 'Potatoes-4', 18.47, 103.92, 109.92, 413.88, 0.3],
#  ['Potatoes', 'Potatoes-5', 7.63, 42.94, 46.32, 170.52, 0.46],
#  ['Potatoes', 'Potatoes-6', 9.68, 54.54, 56.2, 216.26, 0.45],
#  ['Potatoes', 'Potatoes-7', 10.53, 55.54, 63.06, 222.62, 0.36],
#  ['Poultry Meat', 'Poultry Meat-0', 206.01, 800.58, 1218.18, 3249.35, 11.99],
#  ['Poultry Meat', 'Poultry Meat-1', 307.46, 1639.4, 1757.8, 6584.93, 9.85],
#  ['Poultry Meat', 'Poultry Meat-2', 311.96, 1756.5, 2030.36, 6880.78, 8.63],
#  ['Prawns (farmed)',
#   'Prawns (farmed)-0',
#   764.9,
#   4392.19,
#   4467.44,
#   17242.31,
#   25.99],
#  ['Prawns (farmed)',
#   'Prawns (farmed)-1',
#   740.8,
#   3153.36,
#   4273.66,
#   12816.82,
#   17.87],
#  ['Prawns (farmed)',
#   'Prawns (farmed)-2',
#   603.86,
#   3251.7,
#   3380.43,
#   12778.28,
#   27.34],
#  ['Prawns (farmed)',
#   'Prawns (farmed)-3',
#   1028.9,
#   5321.88,
#   6064.31,
#   20864.69,
#   27.51],
#  ['Prawns (farmed)',
#   'Prawns (farmed)-4',
#   774.92,
#   4646.32,
#   4600.32,
#   18760.48,
#   17.19],
#  ['Prawns (farmed)',
#   'Prawns (farmed)-5',
#   1013.86,
#   6235.56,
#   6147.37,
#   24474.07,
#   26.83],
#  ['Prawns (farmed)',
#   'Prawns (farmed)-6',
#   817.06,
#   4066.07,
#   4827.71,
#   16228.27,
#   21.16],
#  ['Rice', 'Rice-0', 180.79, 966.25, 1044.79, 3892.86, 3.44],
#  ['Rice', 'Rice-1', 117.56, 540.96, 747.61, 2088.77, 4.65],
#  ['Rice', 'Rice-2', 161.52, 825.55, 901.76, 3376.55, 5.59],
#  ['Rice', 'Rice-3', 119.66, 553.72, 732.73, 2232.04, 3.25],
#  ['Rice', 'Rice-4', 132.17, 667.21, 769.83, 2722.32, 4.09],
#  ['Root Vegetables', 'Root Vegetables-0', 11.07, 58.24, 66.72, 234.06, 0.4],
#  ['Root Vegetables', 'Root Vegetables-1', 17.38, 82.47, 96.31, 323.49, 0.47],
#  ['Root Vegetables', 'Root Vegetables-2', 20.11, 96.0, 121.52, 371.6, 0.45],
#  ['Root Vegetables', 'Root Vegetables-3', 12.37, 50.05, 73.65, 195.69, 0.58],
#  ['Root Vegetables', 'Root Vegetables-4', 9.18, 43.09, 56.24, 175.43, 0.37],
#  ['Root Vegetables', 'Root Vegetables-5', 11.78, 63.4, 70.04, 253.41, 0.39],
#  ['Soymilk', 'Soymilk-0', 28.31, 134.47, 168.15, 520.6, 0.76],
#  ['Soymilk', 'Soymilk-1', 28.53, 145.17, 165.15, 582.87, 1.27],
#  ['Soymilk', 'Soymilk-2', 32.66, 145.67, 194.24, 586.62, 0.99],
#  ['Soymilk', 'Soymilk-3', 32.14, 155.18, 197.35, 626.37, 0.88],
#  ['Soymilk', 'Soymilk-4', 25.19, 120.98, 138.45, 482.35, 1.01],
#  ['Soymilk', 'Soymilk-5', 33.07, 167.07, 199.31, 663.7, 0.77],
#  ['Soymilk', 'Soymilk-6', 33.93, 148.32, 178.89, 606.86, 0.78],
#  ['Tofu (soybeans)', 'Tofu (soybeans)-0', 75.88, 320.5, 445.41, 1223.59, 2.92],
#  ['Tofu (soybeans)',
#   'Tofu (soybeans)-1',
#   94.82,
#   471.84,
#   652.21,
#   1855.84,
#   3.53],
#  ['Tofu (soybeans)', 'Tofu (soybeans)-2', 98.7, 518.02, 631.67, 2124.37, 3.26],
#  ['Tofu (soybeans)', 'Tofu (soybeans)-3', 109.6, 585.46, 653.53, 2340.09, 3.4],
#  ['Tomatoes', 'Tomatoes-0', 75.91, 378.93, 445.35, 1491.01, 2.77],
#  ['Tomatoes', 'Tomatoes-1', 99.27, 423.23, 596.07, 1669.54, 2.88],
#  ['Tomatoes', 'Tomatoes-2', 97.56, 525.47, 576.31, 2107.42, 2.59],
#  ['Tomatoes', 'Tomatoes-3', 73.03, 342.03, 433.54, 1369.23, 1.23],
#  ['Tomatoes', 'Tomatoes-4', 67.99, 353.58, 422.49, 1394.12, 1.73],
#  ['Tomatoes', 'Tomatoes-5', 70.73, 353.91, 434.27, 1444.99, 1.86],
#  ['Tomatoes', 'Tomatoes-6', 64.15, 367.8, 397.65, 1502.15, 2.13],
#  ['Wheat & Rye', 'Wheat & Rye-0', 46.31, 174.83, 285.04, 699.15, 1.4],
#  ['Wheat & Rye', 'Wheat & Rye-1', 60.58, 286.94, 346.67, 1160.57, 1.1],
#  ['Wheat & Rye', 'Wheat & Rye-2', 47.44, 239.78, 284.22, 976.03, 1.75],
#  ['Wheat & Rye', 'Wheat & Rye-3', 51.99, 255.85, 326.5, 1021.12, 1.42],
#  ['Wheat & Rye', 'Wheat & Rye-4', 56.81, 313.55, 359.81, 1242.72, 1.78],
#  ['Wheat & Rye', 'Wheat & Rye-5', 42.18, 228.77, 257.25, 904.92, 1.63],
#  ['Wheat & Rye', 'Wheat & Rye-6', 40.71, 207.71, 220.36, 848.26, 1.62],
#  ['Wheat & Rye', 'Wheat & Rye-7', 55.78, 268.09, 355.82, 1049.97, 1.43],
#  ['Wheat & Rye', 'Wheat & Rye-8', 54.42, 282.15, 315.34, 1147.74, 1.9],
#  ['Wine', 'Wine-0', 40.67, 146.14, 219.12, 589.92, 2.11],
#  ['Wine', 'Wine-1', 37.91, 183.95, 251.14, 742.54, 1.76],
#  ['Wine', 'Wine-2', 51.23, 290.09, 328.82, 1149.29, 1.65],
#  ['Wine', 'Wine-3', 103.68, 544.65, 555.35, 2199.36, 2.45],
#  ['Wine', 'Wine-4', 57.87, 238.68, 362.57, 944.59, 1.21],
#  ['Wine', 'Wine-5', 53.05, 273.4, 308.46, 1113.18, 1.56],
#  ['Wine', 'Wine-6', 62.46, 339.51, 387.91, 1371.44, 2.29],
#  ['Wine', 'Wine-7', 55.04, 319.0, 345.65, 1277.0, 1.38],
#  ['Wine', 'Wine-8', 59.97, 328.83, 387.77, 1301.2, 1.42]]

# %%
sim_list_df = pd.DataFrame(sim_list)
sim_list_df.columns = ["category", "article", "weight", "price", "calories", "health_score", "co2"]

# %%
sim_list_df
# Out:
#     category    article  weight   price  calories  health_score   co2
# 0     Apples   Apples-0   14.78   66.97     77.68        267.47  0.43
# 1     Apples   Apples-1   10.72   56.73     59.31        225.46  0.50
# 2     Apples   Apples-2   15.47   79.07    100.04        312.04  0.24
# 3    Bananas  Bananas-0   22.47  101.36    146.21        400.53  0.95
# 4    Bananas  Bananas-1   26.25  134.98    152.01        536.40  0.70
# ..       ...        ...     ...     ...       ...           ...   ...
# 222     Wine     Wine-4   57.87  238.68    362.57        944.59  1.21
# 223     Wine     Wine-5   53.05  273.40    308.46       1113.18  1.56
# 224     Wine     Wine-6   62.46  339.51    387.91       1371.44  2.29
# 225     Wine     Wine-7   55.04  319.00    345.65       1277.00  1.38
# 226     Wine     Wine-8   59.97  328.83    387.77       1301.20  1.42
#
# [227 rows x 7 columns]

# %%
sim_list_df.to_csv("data/sim_food.csv")
